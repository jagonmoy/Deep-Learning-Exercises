# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/admin/Documents/datasets/sonar_dataset.csv',header = None)
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 138  0.0731  0.1249  0.1665  0.1496  0.1443  0.2770  0.2555  0.1712  0.0466
# 130  0.0443  0.0446  0.0235  0.1008  0.2252  0.2611  0.2061  0.1668  0.1801
# 181  0.0423  0.0321  0.0709  0.0108  0.1070  0.0973  0.0961  0.1323  0.2462
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 189  0.0158  0.0239  0.0150  0.0494  0.0988  0.1425  0.1463  0.1219  0.1697
#
#          9   ...      51      52      53      54      55      56      57  \
# 138  0.1114  ...  0.0444  0.0230  0.0290  0.0141  0.0161  0.0177  0.0194
# 130  0.3083  ...  0.0274  0.0205  0.0141  0.0185  0.0055  0.0045  0.0115
# 181  0.2696  ...  0.0176  0.0035  0.0093  0.0121  0.0075  0.0056  0.0021
# 10   0.0452  ...  0.0062  0.0120  0.0052  0.0056  0.0093  0.0042  0.0003
# 189  0.1923  ...  0.0121  0.0108  0.0057  0.0028  0.0079  0.0034  0.0046
#
#          58      59  60
# 138  0.0207  0.0057   M
# ...

# %%
# checking whether there is any column which has null value

df.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
x = df.drop(60,axis="columns")
y = df[60]

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
# implementing one hot encoding for y and then deleting the first column

y = pd.get_dummies(y,drop_first=True)
y.sample(5)
# Out:
#      R
# 23   1
# 84   1
# 138  0
# 112  0
# 21   1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train.shape
# Out:
# (156, 60)

# %%
x_test.shape
# Out:
# (52, 60)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid'),
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.fit(x_train,y_train,epochs=100,batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.6800 - accuracy: 0.5385
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6554 - accuracy: 0.5833
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6203 - accuracy: 0.7115
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 0.6538
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5797 - accuracy: 0.7756
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7756
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.8397
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4891 - accuracy: 0.8333
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4902 - accuracy: 0.7949
# Epoch 10/100
# ...

# %%
# as you can see for train dataset it is showing accuracy of 100% 
# now let us see how it performs with test dataset

model.evaluate(x_test,y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1424 - accuracy: 0.7692
# [1.1423864364624023, 0.7692307829856873]

# %%
# as you can see for test dataset it's accuracy is 0.7692 . This is a overfitting problem now let use solve
# this by adding a dropout layer after each hidden layer

model_dropout = keras.Sequential([
    keras.layers.Dense(60,input_shape=(60,),activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid'),
])

model_dropout.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model_dropout.fit(x_train,y_train,epochs=100,batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 5ms/step - loss: 0.7499 - accuracy: 0.4679
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7177 - accuracy: 0.4936
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7080 - accuracy: 0.5064
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6961 - accuracy: 0.5064
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6939 - accuracy: 0.5321
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5385
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6623 - accuracy: 0.6090
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6943 - accuracy: 0.5064
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.4936
# Epoch 10/100
# ...

# %%
# now for train data set accuracy is 0.88 let us check accuracy for test dataset

model_dropout.evaluate(x_test,y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4347 - accuracy: 0.8077
# [0.4346502423286438, 0.807692289352417]

# %%
# see now for test dataset accuracy is better than previous one with no dropout layer
